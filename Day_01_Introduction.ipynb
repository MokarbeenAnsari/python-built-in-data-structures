# %% [markdown]
# ### **What is Data Structure?**

# %% [markdown]
# A data structure is a way of **storing** and **organizing** data according to a certain **format or structure**.
#
# Data structures are a crucial part of computer programming. Since we frequently deal with data manipulation, it is of paramount importance to organize it in an **efficient and meaningful way** so that we can also access in efficient way.

# %% [markdown]
# ### **Built-in Data Structure in Python**

# %% [markdown]
# Python is equipped with several built-in data structures to help us efficiently handle large amounts of data.
#
# The **four** primary built-in data structures offered in Python3 are:
# - **List**
# - **Tuple**
# - **Dictionary**
# - **Set**

# %% [markdown]
# ### **What are we going to study?**

# %% [markdown]
# Build-in data structure play a very important role, when we solve any problem while solving the problem. Since it save the implementation time since this is already implemented in optimized ways.
#
# **String** is also one of the important data structure which we use most of the time.
#
# So in this series we are going to study **5** built-in data structure:
# - **String**
# - **List**
# - **Tuple**
# - **Dictionary**
# - **Set**
